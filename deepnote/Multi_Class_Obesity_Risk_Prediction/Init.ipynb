# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 2)) (23.0.1)
# Requirement already satisfied: gower==0.1.2 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: xgboost in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: shap in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 5)) (0.47.2)
# Requirement already satisfied: scikit-learn==1.6.1 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: lazypredict in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 7)) (0.2.16)
# Requirement already satisfied: numpy in /root/venv/lib/python3.10/site-packages (from gower==0.1.2->-r ./requirements.txt (line 3)) (1.25.2)
# Requirement already satisfied: scipy in /root/venv/lib/python3.10/site-packages (from gower==0.1.2->-r ./requirements.txt (line 3)) (1.9.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn==1.6.1->-r ./requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn==1.6.1->-r ./requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /root/venv/lib/python3.10/site-packages (from xgboost->-r ./requirements.txt (line 4)) (2.26.5)
# Requirement already satisfied: packaging>20.9 in /root/venv/lib/python3.10/site-packages (from shap->-r ./requirements.txt (line 5)) (24.2)
# Requirement already satisfied: typing-extensions in /root/venv/lib/python3.10/site-packages (from shap->-r ./requirements.txt (line 5)) (4.13.2)
# Requirement already satisfied: slicer==0.0.8 in /root/venv/lib/python3.10/site-packages (from shap->-r ./requirements.txt (line 5)) (0.0.8)
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.10/site-packages (from shap->-r ./requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: pandas in /root/venv/lib/python3.10/site-packages (from shap->-r ./requirements.txt (line 5)) (2.1.4)
# Requirement already satisfied: tqdm>=4.27.0 in /root/venv/lib/python3.10/site-packages (from shap->-r ./requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: numba>=0.54 in /root/venv/lib/python3.10/site-packages (from shap->-r ./requirements.txt (line 5)) (0.61.2)
# Requirement already satisfied: pytest-runner in /root/venv/lib/python3.10/site-packages (from lazypredict->-r ./requirements.txt (line 7)) (6.0.1)
# Requirement already satisfied: click in /root/venv/lib/python3.10/site-packages (from lazypredict->-r ./requirements.txt (line 7)) (8.1.8)
# Requirement already satisfied: lightgbm in /root/venv/lib/python3.10/site-packages (from lazypredict->-r ./requirements.txt (line 7)) (4.6.0)
# Requirement already satisfied: mlflow>=2.0.0 in /root/venv/lib/python3.10/site-packages (from lazypredict->-r ./requirements.txt (line 7)) (2.22.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.13.2)
# Requirement already satisfied: gunicorn<24 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (23.0.0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (2.22.0)
# Requirement already satisfied: matplotlib<4 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.6.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: markdown<4,>=3.3 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.8)
# Requirement already satisfied: graphene<4 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.4.3)
# Requirement already satisfied: Flask<4 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (17.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.4.42)
# Requirement already satisfied: Jinja2<4,>=2.11 in /root/venv/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: fastapi<1 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.1.44)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (5.5.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.52.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.32.1)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.10.22)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.5.0)
# Requirement already satisfied: requests<3,>=2.17.3 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.32.1)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (8.6.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (4.25.7)
# Requirement already satisfied: uvicorn<1 in /root/venv/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.34.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /root/venv/lib/python3.10/site-packages (from numba>=0.54->shap->-r ./requirements.txt (line 5)) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.10/site-packages (from pandas->shap->-r ./requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas->shap->-r ./requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas->shap->-r ./requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: Mako in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.3.5)
# Requirement already satisfied: urllib3>=1.26.0 in /root/venv/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: blinker>=1.9 in /root/venv/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2 in /root/venv/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: Werkzeug>=3.1 in /root/venv/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.1.3)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /root/venv/lib/python3.10/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /root/venv/lib/python3.10/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (4.57.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.2.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (11.2.1)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->shap->-r ./requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: google-auth~=2.0 in /root/venv/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (2.40.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /root/venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.46.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /root/venv/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /root/venv/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /root/venv/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /root/venv/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.53b1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in /root/venv/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /root/venv/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /root/venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (5.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /root/venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /root/venv/lib/python3.10/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /root/venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /root/venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /root/venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict->-r ./requirements.txt (line 7)) (0.6.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade ipywidgets jupyter
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 6.3 MB/s eta 0:00:00
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /root/venv/lib/python3.10/site-packages (from ipywidgets) (8.36.0)
# Requirement already satisfied: comm>=0.1.3 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 66.5 MB/s eta 0:00:00
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /root/venv/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 38.2 MB/s eta 0:00:00
# Collecting jupyterlab
#   Downloading jupyterlab-4.4.2-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 72.6 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyter) (6.29.5)
# Collecting notebook
#   Downloading notebook-7.4.2-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 78.0 MB/s eta 0:00:00
# Requirement already satisfied: pexpect>4.3 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: typing_extensions>=4.6 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: exceptiongroup in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: decorator in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: stack_data in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: tornado>=6.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: packaging in /root/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (24.2)
# Requirement already satisfied: debugpy>=1.6.5 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.5)
# Requirement already satisfied: psutil in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: nest-asyncio in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: pyzmq>=24 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter) (7.4.9)
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 19.1 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.27.1
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 10.4 MB/s eta 0:00:00
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 60.2 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.2.2 in /root/venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: jinja2>=3.0.3 in /root/venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (3.1.6)
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools>=41.1.0 in /root/venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (65.5.0)
# Collecting httpx>=0.25.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 21.2 MB/s eta 0:00:00
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 18.7 MB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: nbformat>=5.7 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from nbconvert->jupyter) (5.10.4)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: markupsafe>=2.0 in /root/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (3.0.2)
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 38.3 MB/s eta 0:00:00
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 53.0 MB/s eta 0:00:00
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /root/venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.4.26)
# Requirement already satisfied: idna in /root/venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: anyio in /root/venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.9.0)
# Requirement already satisfied: h11>=0.16 in /root/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /root/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: entrypoints in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /root/venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.7)
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 11.3 MB/s eta 0:00:00
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: babel>=2.10 in /root/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Collecting json5>=0.9.0
#   Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: requests>=2.31 in /root/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: jsonschema>=4.18.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Requirement already satisfied: executing>=1.2.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: pure-eval in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /root/venv/lib/python3.10/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: rpds-py>=0.7.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.0)
# Requirement already satisfied: attrs>=22.2.0 in /root/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: referencing>=0.28.4 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.12.1)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in /root/venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.4.0)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: cffi>=1.0.1 in /root/venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /root/venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 19.2 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, widgetsnbextension, websocket-client, webcolors, uri-template, types-python-dateutil, tinycss2, terminado, soupsieve, send2trash, rfc3986-validator, rfc3339-validator, python-json-logger, prometheus-client, pandocfilters, overrides, mistune, jupyterlab_widgets, jupyterlab-pygments, jsonpointer, json5, httpcore, fqdn, defusedxml, bleach, async-lru, jupyter-server-terminals, httpx, beautifulsoup4, arrow, argon2-cffi-bindings, isoduration, ipywidgets, argon2-cffi, jupyter-console, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 beautifulsoup4-4.13.4 bleach-6.2.0 defusedxml-0.7.1 fqdn-1.5.1 httpcore-1.0.9 httpx-0.28.1 ipywidgets-8.1.7 isoduration-20.11.0 json5-0.12.0 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.2 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab_widgets-3.0.15 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 notebook-7.4.2 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.21.1 python-json-logger-3.3.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 soupsieve-2.7 terminado-0.18.1 tinycss2-1.4.0 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.14
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a441f35e-4b4c-4c50-b56a-1aea6b800ed8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
